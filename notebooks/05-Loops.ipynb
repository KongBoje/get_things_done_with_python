# %% [markdown]
# # `for` Loops
#
# ## Iterating over Lists and Sequences

# %%
for i in [0, 1, 2, 3]:
    print(i)
# Out:
# 0
# 1
# 2
# 3

# %%
for i in range(4):
    print(i)
# Out:
# 0
# 1
# 2
# 3

# %% [markdown]
# ## Iterating over Lists and Sequences with Indices
#
# In case you want to iterate over a list or sequence of values in and you need to have access to the index of each element, you could do the following:

# %%
values = range(4, 0, -1)
for idx in range(len(values)):
    print(idx, values[idx])
# Out:
# 0 4
# 1 3
# 2 2
# 3 1

# %% [markdown]
# However, **do not do it as shown above**! First, it is more complicated and second, it is not "Pythonic". Instead do the following:

# %%
for idx, value in enumerate(range(4, 0, -1)):
    print(idx, value)
# Out:
# 0 4
# 1 3
# 2 2
# 3 1

# %% [markdown]
# ## Checking Lists for Element Containment

# %%
1 in [0, 1, 2, 3]
# Out:
# True

# %%
1 in range(4, 0, -1)
# Out:
# True

# %%
'Hej' in [0, 1, 2, 3]
# Out:
# False

# %%
1 in ['Call', 'me', 'Ishmael']
# Out:
# False

# %%
'Hej' in ['Call', 'me', 'Ishmael']
# Out:
# False

# %%
# %timeit 55000 in range(1000000)
# Out:
# The slowest run took 10.92 times longer than the fastest. This could mean that an intermediate result is being cached.
# 1000000 loops, best of 3: 294 ns per loop

# %%
def is_in(el, values):
    for value in values:
        if el == value:
            return True
        
# %timeit is_in(55000, range(1000000))
# Out:
# 1000 loops, best of 3: 1.73 ms per loop

# %% [markdown]
# # `while` Loops
#
# The `for` loop takes a collection of items and executes a block of code once for each item in the collection. In contrast, the `while` loop runs as long as, or while, a certain condition is `True`.
#
# It has the syntax:
#
# ```python
# while boolean_expression:
#     pass
# ```

# %%
# counting to five
current_number = 0

while current_number <= 5:
    print(current_number)
    current_number += 1
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# A computer program's main loop, such as the one of this notebook, is very likely implemented via a `while` loop.
#
# To exit a `while` loop immediately without running any remaining code in the loop, regardless of the results of any conditional test, use the break statement. The `break` statement directs the  ow of your program; you can use it to control which lines of code are executed and which are not, so the program only executes code that you want it to, when you want it to.
#
# Note, you can use the `break` statement in any of Python’s loops. For example, you could use break to quit a for loop that is working through a list or a dictionary.

# %%
while True:
    expression = input()
    if expression == 'quit!':
        break
    print(eval(expression))
# Out:
# 5 +6
# 11
# print('Hej')
# Hej
# None
# quit!

# %% [markdown]
# Rather than breaking out of a loop entirely without executing the rest of its code, you can use the `continue` statement to return to the beginning of the loop based on the result of a conditional test.

# %%
while True:
    expression = input()
    if expression == 'quit!':
        break
    if expression == 'nop!':
        continue
    print(eval(expression))
# Out:
# nop!
# nop!
# 3 + 9
# 12
# quit!

# %%
eval?

# %% [markdown]
# # Exercises!!!
#
# ![image](https://media.giphy.com/media/13HgwGsXF0aiGY/giphy.gif)
#
#
#   1. Write a program that generates via a loop 20 random project group names consisting of `Adjective Noun` combinations.
#       * Find a list of most common English nouns and adjectives online - with at least 100 entries each.
#       * Keep the source of these lists as comments in your programs
#       * **Hint** you can use the standard libraries `random.choice()` function. Figure out how to use it by typing
#       ```python
#       import random
#       random.choice?
#       ```
#         into your interactive environment.
#   2. Write a program that creates gramatically valid English sentences.
#     * Here, we consider a sentence to be gramatically correct when it follows the simple English grammar of the form: `Article Noun Verb.` That is, even the sentence `A insect fly.` is, for the moment, considered correct.
#     * Create additionally to the exercise above, a list of definite and indefinite articles and verbs from an online resource.
#   3. Extend the above program to generate all possible sentences with the given words.

# %%
import random

adject = ['Adamant', 'unyielding', 'a very hard substance',
'Adroit', 'clever', 'resourceful',
'Amatory', 'sexual',
'Animistic', 'quality of recurrence or reversion to earlier form',
'Antic', 'clownish', 'frolicsome',
'Arcadian', 'serene',
'Baleful', 'deadly', 'foreboding',
'Bellicose', 'quarrelsome',
'Bilious', 'unpleasant', 'peevish',
'Boorish', 'crude', 'insensitive',
'Calamitous', 'disastrous',
'Caustic', 'corrosive', 'sarcastic',
'Cerulean', 'sky blue',]

noun = ['Adamant', 'unyielding', 'a very hard substance',
'Adroit', 'clever', 'resourceful',
'Amatory', 'sexual',
'Animistic', 'quality of recurrence or reversion to earlier form',
'Antic', 'clownish', 'frolicsome',
'Arcadian', 'serene',
'Baleful', 'deadly', 'foreboding',
'Bellicose', 'quarrelsome',
'Bilious', 'unpleasant', 'peevish',
'Boorish', 'crude', 'insensitive',
'Calamitous', 'disastrous',
'Caustic', 'corrosive', 'sarcastic',
'Cerulean', 'sky blue',]

randomAdjec = random.choice(adject)
randomNoun = random.choice(noun)
print((' ').join([randomAdjec, randomNoun]))
# Out:
# Cerulean a very hard substance

# %%
import random

# https://www.espressoenglish.net/100-common-adjectives-in-english/

adj = ["other",
"new",
"good",
"high",
"old",
"great",
"big",
"American",
"small",
"large",
"national",
"young",
"different",
"black",
"long",
"little",
"important",
"political",
"bad",
"white",
"real",
"best",
"right",
"social",
"only",
"public",
"sure",
"low",
"early",
"able",
"human",
"local",
"late",
"hard",
"major",
"better",
"economic",
"strong",
"possible",
"whole",
"free",
"military",
"true",
"federal",
"international",
"full",
"special",
"easy",
"clear",
"recent",
"certain",
"personal",
"open",
"red",
"difficult",
"available",
"likely",
"short",
"single",
"medical",
"current",
"wrong",
"private",
"past",
"foreign",
"fine",
"common",
"poor",
"natural",
"significant",
"similar",
"hot",
"dead",
"central",
"happy",
"serious",
"ready",
"simple",
"left",
"physical",
"general",
"environmental",
"financial",
"blue",
"democratic",
"dark",
"various",
"entire",
"close",
"legal",
"religious",
"cold",
"final",
"main",
"green",
"nice",
"huge",
"popular",
"traditional",
"cultural"]

articles = ["the", "a", "an"]

# https://www.espressoenglish.net/100-common-nouns-in-english/

nouns = ["time",
"year",
"people",
"way",
"day",
"man",
"thing",
"woman",
"life",
"child",
"world",
"school",
"state",
"family",
"student",
"group",
"country",
"problem",
"hand",
"part",
"place",
"case",
"week",
"company",
"system",
"program",
"question",
"work",
"government",
"number",
"night",
"point",
"home",
"water",
"room",
"mother",
"area",
"money",
"story",
"fact",
"month",
"lot",
"right",
"study",
"book",
"eye",
"job",
"word",
"business",
"issue",
"side",
"kind",
"head",
"house",
"service",
"friend",
"father",
"power",
"hour",
"game",
"line",
"end",
"member",
"law",
"car",
"city",
"community",
"name",
"president",
"team",
"minute",
"idea",
"kid",
"body",
"information",
"back",
"parent",
"face",
"others",
"level",
"office",
"door",
"health",
"person",
"art",
"war",
"history",
"party",
"result",
"change",
"morning",
"reason",
"research",
"girl",
"guy",
"moment",
"air",
"teacher",
"force",
"education"]

# https://www.espressoenglish.net/100-most-common-english-verbs/

verbs = ["be",
"have",
"do",
"say",
"go",
"can",
"get",
"would",
"make",
"know",
"will",
"think",
"take",
"see",
"come",
"could",
"want",
"look",
"use",
"find",
"give",
"tell",
"work",
"may",
"should",
"call",
"try",
"ask",
"need",
"feel",
"become",
"leave",
"put",
"mean",
"keep",
"let",
"begin",
"seem",
"help",
"talk",
"turn",
"start",
"might",
"show",
"hear",
"play",
"run",
"move",
"like",
"live",
"believe",
"hold",
"bring",
"happen",
"must",
"write",
"provide",
"sit",
"stand",
"lose",
"pay",
"meet",
"include",
"continue",
"set",
"learn",
"change",
"lead",
"understand",
"watch",
"follow",
"stop",
"create",
"speak",
"read",
"allow",
"add",
"spend",
"grow",
"open",
"walk",
"win",
"offer",
"remember",
"love",
"consider",
"appear",
"buy",
"wait",
"serve",
"die",
"send",
"expect",
"build",
"stay",
"fall",
"cut",
"reach",
"kill",
"remain"]

for i in range(20):
    tmpA = random.randint(0, len(articles)-1)
    tmpB = random.randint(0, len(nouns)-1)
    tmpC = random.randint(0, len(verbs)-1)
    
    print(articles[tmpA] + " " + nouns[tmpB] + " " + verbs[tmpC])
# Out:
# a family see
# the book want
# an people pay
# an information move
# a hour seem
# the woman die
# the result hold
# an country change
# a health consider
# a change say
# an guy expect
# a system serve
# the month lose
# the area follow
# the force fall
# a door grow
# an car want
# a service buy
# the law tell
# a case speak

# %%
sentences = []
for a in range(len(articles)):
    for b in range(len(nouns)):
        for c in range(len(verbs)):
            sentences.append(articles[a] + " " + nouns[b] + " " + verbs[c])
            
print(sentences)
# Out:
# ['the time be', 'the time have', 'the time do', 'the time say', 'the time go', 'the time can', 'the time get', 'the time would', 'the time make', 'the time know', 'the time will', 'the time think', 'the time take', 'the time see', 'the time come', 'the time could', 'the time want', 'the time look', 'the time use', 'the time find', 'the time give', 'the time tell', 'the time work', 'the time may', 'the time should', 'the time call', 'the time try', 'the time ask', 'the time need', 'the time feel', 'the time become', 'the time leave', 'the time put', 'the time mean', 'the time keep', 'the time let', 'the time begin', 'the time seem', 'the time help', 'the time talk', 'the time turn', 'the time start', 'the time might', 'the time show', 'the time hear', 'the time play', 'the time run', 'the time move', 'the time like', 'the time live', 'the time believe', 'the time hold', 'the time bring', 'the time happen', 'the time must', 'the time write', 'the time provide', 'the time sit', 'the time stand', 'the time lose', 'the time pay', 'the time meet', 'the time include', 'the time continue', 'the time set', 'the time learn', 'the time change', 'the time lead', 'the time understand', 'the time watch', 'the time follow', 'the time stop', 'the time create', 'the time speak', 'the time read', 'the time allow', 'the time add', 'the time spend', 'the time grow', 'the time open', 'the time walk', 'the time win', 'the time offer', 'the time remember', 'the time love', 'the time consider', 'the time appear', 'the time buy', 'the time wait', 'the time serve', 'the time die', 'the time send', 'the time expect', 'the time build', 'the time stay', 'the time fall', 'the time cut', 'the time reach', 'the time kill', 'the time remain', 'the year be', 'the year have', 'the year do', 'the year say', 'the year go', 'the year can', 'the year get', 'the year would', 'the year make', 'the year know', 'the year will', 'the year think', 'the year take', 'the year see', 'the year come', 'the year could', 'the year want', 'the year look', 'the year use', 'the year find', 'the year give', 'the year tell', 'the year work', 'the year may', 'the year should', 'the year call', 'the year try', 'the year ask', 'the year need', 'the year feel', 'the year become', 'the year leave', 'the year put', 'the year mean', 'the year keep', 'the year let', 'the year begin', 'the year seem', 'the year help', 'the year talk', 'the year turn', 'the year start', 'the year might', 'the year show', 'the year hear', 'the year play', 'the year run', 'the year move', 'the year like', 'the year live', 'the year believe', 'the year hold', 'the year bring', 'the year happen', 'the year must', 'the year write', 'the year provide', 'the year sit', 'the year stand', 'the year lose', 'the year pay', 'the year meet', 'the year include', 'the year continue', 'the year set', 'the year learn', 'the year change', 'the year lead', 'the year understand', 'the year watch', 'the year follow', 'the year stop', 'the year create', 'the year speak', 'the year read', 'the year allow', 'the year add', 'the year spend', 'the year grow', 'the year open', 'the year walk', 'the year win', 'the year offer', 'the year remember', 'the year love', 'the year consider', 'the year appear', 'the year buy', 'the year wait', 'the year serve', 'the year die', 'the year send', 'the year expect', 'the year build', 'the year stay', 'the year fall', 'the year cut', 'the year reach', 'the year kill', 'the year remain', 'the people be', 'the people have', 'the people do', 'the people say', 'the people go', 'the people can', 'the people get', 'the people would', 'the people make', 'the people know', 'the people will', 'the people think', 'the people take', 'the people see', 'the people come', 'the people could', 'the people want', 'the people look', 'the people use', 'the people find', 'the people give', 'the people tell', 'the people work', 'the people may', 'the people should', 'the people call', 'the people try', 'the people ask' ...
